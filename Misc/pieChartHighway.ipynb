# %%
import matplotlib.pyplot as plt

labels = ["Sky", "leftDesert", "leftRoad", "leftYellowLine", "middleRoad", "rightYellowLine", "rightRoad", "rightDesert"]
labelsForLegend = ["Sky", "Desert", "Road", "Road Line"]
values = [85, 43, 13, 1.5, 1, 1.5, 11, 14]
colours = ["#02a4d0", "#cd6408", "#614b40", "#fdcd00", "#614b40", "#fdcd00", "#614b40","#cd6408"]

plt.pie(values, colors=colours)

plt.legend(labelsForLegend, loc = "upper right", bbox_to_anchor=(1.3, 0.9))

plt.show()
