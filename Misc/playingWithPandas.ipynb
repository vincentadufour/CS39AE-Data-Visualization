# %%
import pandas as ps

df = ps.read_csv('data.csv')

print(df)

# retrieve maximum
print(ps.options.display.max_rows)

# retrieve one column titled, 'age'
print(df['age'])

# to print datatypes
print(df.dtypes)

# to print a lot of info about dataset
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as ps
# ----> 3 df = ps.read_csv('data.csv')
#       5 print(df)
#       7 ## retrieve maximum
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
data = pd.Series([30, 20, 50], index=['Category A', 'Category B', 'Category C'])
data.plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Sample DataFrame
df = pd.DataFrame({
    'A': np.random.rand(10),
    'B': np.random.rand(10),
    'C': np.random.rand(10)
})

# Customized line plot
ax = df.plot(
    kind='line', 
    title='Customized Line Plot', 
    xlabel='X Axis Label', 
    ylabel='Y Axis Label',
    figsize=(10, 6), 
    grid=True
)
ax.set_yscale('log')  # Set y-axis to logarithmic scale

# %%
import pandas as pd
import numpy as np

# Sample data
#Assume the data frame is 

df = pd.DataFrame(data)

# 1. Handling missing data
print("Original DataFrame:\n", df)
df['Age'].fillna(df['Age'].mean(), inplace=True)  # Impute missing values with mean

# 2. Removing duplicates
df = df.drop_duplicates()

# 3. Handling outliers
df['Score'] = np.where(df['Score'] > 100, 100, df['Score'])  # Cap outliers

# 4. Standardizing inconsistent data
df['Country'] = df['Country'].replace({'U.S.A.': 'USA'})  # Correct inconsistent country names

# Final cleaned data
print("\nCleaned DataFrame:\n", df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       2 import numpy as np
#       4 # Sample data
#       5 #Assume the data frame is
# ----> 7 df = pd.DataFrame(data)
#       9 # 1. Handling missing data
#      10 print("Original DataFrame:\n", df)
#
# NameError: name 'data' is not defined
