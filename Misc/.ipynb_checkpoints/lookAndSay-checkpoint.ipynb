# %% [markdown]
# # Look-And-Say Sequence Graphs
# The below is an attempt to find different ways to graph the Look-And-Say sequence to n iterations.

# %%
import matplotlib.pyplot as plt

# look-and-say sequence
def look_and_say(n):
    sequence = "1"
    for _ in range(n - 1):
        next_sequence = ""
        i = 0
        while i < len(sequence):
            count = 1
            while i + 1 < len(sequence) and sequence[i] == sequence[i + 1]:
                i += 1
                count += 1
            next_sequence += str(count) + sequence[i]
            i += 1
        sequence = next_sequence
    return sequence

# count the frequency of each number
def count_digits(sequence):
    counts = {"1": 0, "2": 0, "3": 0}
    for digit in sequence:
        if digit in counts:
            counts[digit] += 1
    return counts

# plot using matplotLib
def plot_counts(counts):
    labels = list(counts.keys())
    values = list(counts.values())

    bars = plt.bar(labels, values, color=['blue', 'orange', 'green'])

    for bar in bars: 
      plt.text( 
        bar.get_x() + bar.get_width() / 2, # X position: center of each bar 
        bar.get_height(), # Y position: height of each bar 
        bar.get_height(), # Text to display (the height of the bar) 
        ha='center', # Horizontal alignment 
        va='bottom' # Vertical alignment 
      )
    
    plt.xlabel('Digit')
    plt.ylabel('Frequency')
    plt.title('Frequency of Digits in Look-And-Say Sequence')
    plt.show()

    

def look_and_say_analysis(iterations):
    sequence = look_and_say(iterations)
    counts = count_digits(sequence)
    plot_counts(counts)

# Example usage
look_and_say_analysis(20)

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

def look_and_say_generator(n):
    sequence = "1"
    yield sequence  # Start with the first sequence
    for _ in range(n - 1):
        next_sequence = ""
        i = 0
        while i < len(sequence):
            count = 1
            while i + 1 < len(sequence) and sequence[i] == sequence[i + 1]:
                i += 1
                count += 1
            next_sequence += str(count) + sequence[i]
            i += 1
        sequence = next_sequence
        yield sequence  # Yield the next sequence

def count_digits(sequence):
    counts = {"1": 0, "2": 0, "3": 0}
    for digit in sequence:
        if digit in counts:
            counts[digit] += 1
    return counts

def animate(i, n, bar_container):
    sequence = next(sequence_generator)
    counts = count_digits(sequence)
    
    values = [counts["1"], counts["2"], counts["3"]]
    for bar, new_height in zip(bar_container.patches, values):
        bar.set_height(new_height)
    ax.set_title(f"Iteration: {i+1}, Sequence: {sequence}")

# Create the figure and axes
fig, ax = plt.subplots()
bar_container = ax.bar(["1", "2", "3"], [0, 0, 0], color=['blue', 'orange', 'green'])
ax.set_xlabel('Digit')
ax.set_ylabel('Frequency')
ax.set_ylim(0, 10)  # Adjust the y-limit according to expected values
ax.set_title("Look-And-Say Sequence")

# Set the number of iterations
n_iterations = 10

# Create a generator for the Look-And-Say sequence
sequence_generator = look_and_say_generator(n_iterations)

# Create the animation
ani = FuncAnimation(fig, animate, frames=n_iterations, fargs=(n_iterations, bar_container), repeat=False)

# Show the animation
plt.show()
