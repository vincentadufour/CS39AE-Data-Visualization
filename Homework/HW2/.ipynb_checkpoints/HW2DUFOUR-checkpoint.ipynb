# %% [markdown]
# **Homework Assignment2 have three sections. Part A,B and C. Complete your answers in this Markdown file and upload the file with all answers in the canvas submission space.**

# %% [markdown]
# **PART A
# For the below given dataset , plot four histograms as subplots in a single visual as a 2 by 2 grid. Add appropriate title, color and labels for the chart.
#     And answer the questions given below.**
#
#     #Use the below libraries only
#     import matplotlib.pyplot as plt
#     import numpy as np

# %%
dataset_1=[58.723206367206785, 51.83342005738352, 71.89802933217672, 41.91701714644849, 41.602781578192236, 44.00607354555978, 28.76104275690193, 44.74244978319239, 42.40867338446302, 51.50393786476208, 53.41755975777159, 68.76170839215887, 59.5042383818605, 44.23096344337597, 41.01585328651642, 54.919191715065054, 36.797667929793576, 68.31458765854353, 61.79440120721287, 45.30824347895295, 32.868654709091224, 63.538723741654124, 48.85460154747382, 62.378163119734616, 34.05572341205633, 44.00624977046227, 50.05243699718183, 50.46980593764742, 45.49934528520756, 56.228499323474985, 39.32379570617405, 48.576205149787064, 51.20295631711899, 55.14438834058749, 57.1161487808889, 38.75357908162131, 34.65885829264378, 62.77676821898509, 53.323140119795916, 42.51513463443446, 65.51151975522524, 51.156746342928585, 61.792971840638266, 50.67518481410109, 70.60747924881987, 67.55340842443204, 47.51035851520926, 59.71570950954356, 56.45375949585147, 63.68631557532349, 40.35076539419896, 56.86051459998439, 60.58424486849588, 32.41260513576886, 38.16741487334225, 29.607678222398995, 47.305931655554424, 57.17542255795962, 65.02357052096028, 50.74094780419775, 66.28615545571292, 36.198985417851084, 32.96617560644845, 49.44452301103381, 53.840654489393074, 49.67305251905907, 29.325578999601234, 49.10879960487212, 36.95530499495147, 56.69672548830039, 53.66598246096848, 40.60120213672645, 44.861330826633065, 39.40786478111048, 49.37320902726828, 59.551423205012384, 40.14273953664456, 55.040465155178445, 44.69742381627559, 42.07127167737656, 48.929696400454425, 39.64757677580626, 44.46350694652818, 38.021221074111516, 69.6472513291639, 50.35263551971729, 43.00274492007414, 52.13979910734222, 48.8767195030917, 47.79030400466777, 56.14166700043425, 57.57507710047305, 44.69498852389472, 44.2418175935532, 47.24948302848356, 26.98078835264415, 34.84808937801448, 63.66874267444525, 66.44967713501283, 47.50963960443622]
dataset_2=[0.37372952321478464, 2.909366218823972, 12.494918749560258, 22.557667543306135, 7.167791122084008, 7.5952950235306895, 1.1336133854066337, 5.9314324608355085, 7.6060679905529, 2.7769280326065333, 3.1367461187854384, 4.73664984802472, 0.20275360750314514, 3.8872476125613575, 2.3755693562362987, 3.9674923023198265, 1.2756310328478127, 22.120798999430246, 9.003988138795599, 11.366329578930316, 15.567090323777911, 6.900364218488852, 0.9093209451745585, 7.702583632948226, 8.839230578713735, 13.682166488084093, 5.6503464938298205, 1.3648466672931223, 3.337621802617039, 4.511148254746234, 10.382246116218617, 8.457817212014195, 4.402067596518061, 43.06195772169812, 9.308330084672093, 2.7079452875679992, 1.0734300462488686, 1.6588829258982587, 2.8230684939514097, 1.7516487495429403, 2.064917454545804, 3.3560584821544652, 1.90402433662887, 22.707514493559152, 0.8363571259200016, 7.434123501127027, 5.283055564893023, 40.3864216601592, 1.188273456974049, 5.072579937424305, 34.89059664126715, 20.062440619681546, 16.986630340361796, 2.9827508353350463, 1.873995327864875, 11.045595986817835, 26.503850949599553, 8.136504219047422, 8.477275614585865, 3.284750308106508, 14.674737584120885, 2.0707798214607083, 3.910878131192326, 5.541445500698305, 7.084849626446985, 2.7761258356960585, 1.2198327214413545, 9.431996574293565, 3.4056336843654176, 8.704530682924435, 1.676647527706798, 6.561213780285275, 7.605472481290779, 0.5321465145712133, 4.103836013804233, 1.443493268319316, 0.6547225877252488, 46.012013113953245, 3.8913002251942026, 16.600706137698985, 2.938888342934014, 11.441413510203516, 14.280662228282086, 9.054465941691397, 6.378566440452717, 5.307578135053777, 4.290433017039748, 26.52556048220781, 17.75607071141798, 33.53176389415692, 1.3272854183610554, 13.125513634605074, 27.861272652612406, 1.9995580970079767, 0.6881031747249687, 13.513931531886222, 8.544271441986698, 18.44077141321478, 1.505582464141926, 15.860501110318681]
dataset_3=[27.561968879637533, 27.837209060901895, 31.972260711891483, 27.895077595898684, 31.448874284482066, 40.37700399322719, 34.35562351715846, 28.369882339160796, 36.00606961081972, 27.959623134892244, 19.80937732411073, 24.95956844541298, 20.646040394870724, 28.24243257979346, 30.092091895947757, 38.382186561376415, 31.634636868820813, 28.90449735595568, 34.14702790591745, 18.944323454960575, 31.178072790542828, 33.85432596943483, 22.607068771100792, 35.71877021603464, 31.69248203747207, 27.923560430495993, 33.163909330531425, 41.35346428902198, 30.909331275292477, 31.24110293150168, 27.70319550229878, 25.75077815267604, 34.15167908272123, 25.719580870455665, 30.357831186096963, 27.611712766174417, 32.39489912873196, 31.66831052643474, 35.1876997212895, 27.449918005726264, 28.650625323533145, 25.106181421088465, 27.77853369961944, 31.88650246522426, 33.78494308322676, 25.389173379111874, 34.3480296005283, 36.778189294024756, 32.067174516118506, 39.38397906279033, 66.13105400448214, 63.776726483442914, 61.10639875547861, 77.48022155744592, 73.27182828177028, 69.72207664544773, 71.3998431315991, 64.37255476350812, 82.22875989808414, 70.64610590987614, 70.54697397302446, 73.62883311949346, 72.40504615868356, 71.11942012139566, 66.04762772277344, 72.35734178567998, 79.41012248237517, 76.7271002307749, 77.96593313319698, 67.44392161784407, 65.0519758987071, 69.37106539950176, 70.27862456144348, 75.47095759235474, 61.5376768514259, 77.64775159730307, 69.20996050710505, 67.8655946502629, 64.93947812369916, 61.72571664067115, 74.11585291980957, 70.36658983594202, 63.55019550129473, 63.52460613968192, 68.32107650354936, 78.34510762644696, 68.70204324318198, 62.48428523440947, 68.77128467957027, 68.63638215126164, 56.515566785292144, 69.72852566741093, 68.84532734895662, 73.48103182406709, 79.24478047472672, 75.63282514773879, 68.65555654722584, 64.46737045629165, 82.8667990162493, 70.29609217007244]
dataset_4=[50.13929291912946, 49.758749128899964, 51.98084760767855, 48.556395880760576, 44.26337993119763, 44.53141058759608, 49.672467297840015, 44.56575228866235, 42.871542173228356, 51.064302276918966, 47.450227825791444, 65.0399298858269, 23.490301916069882, 60.91506851922462, 62.46085192497629, 29.266097675918505, 46.573124059196516, 46.28559134004209, 35.924883052821784, 42.22183312409125, 38.894241545341714, 67.52270443423623, 59.35678393147461, 62.71555094994159, 57.21672064043235, 38.70948228782771, 44.75479733720226, 54.89374561227918, 37.778721911080545, 57.12998430172388, 47.59674601841865, 46.251791924504026, 57.10959968203491, 54.4426331148604, 46.3903383418092, 61.59329803364248, 39.189366724001026, 56.15935606944264, 55.93101257968384, 46.904535606860094, 53.26133022242118, 37.488864236146966, 59.24027019206901, 48.15097863557011, 44.772769794809605, 60.49009225836889, 42.95656309457241, 35.91538703636441, 34.433708264760966, 56.06009951345639, 37.19570647503717, 67.54794181984364, 29.18070592116278, 66.96456368290038, 52.11017467202618, 49.032868881296075, 44.550809131910505, 53.991361143520706, 49.62365297575152, 61.03301882016521, 51.142276486620396, 51.50301761461878, 46.36387787786144, 49.43054376278933, 53.07801768892059, 32.89831607343375, 36.518145778942866, 57.43264094022715, 51.708654381279416, 48.16016663647321, 50.184339330653934, 53.47581705361671, 44.60240319690639, 42.216952745976876, 51.958452550976816, 40.21627222384968, 54.082527557144715, 32.9741639576216, 60.29155637325644, 54.72597482413043, 52.56029734313876, 59.82690983945514, 66.65474444462576, 60.1437006501813, 31.591257686683548, 37.204230332642986, 43.75181422304321, 50.26091050210834, 55.17659020469123, 42.742561868465344, 51.86766764477078, 42.44617067646678, 43.884821970080516, 35.93338903151778, 40.76766753889096, 113.24157697191833, 115.12063373511333, 125.2682089830392, 115.25300555584029, 133.16191032418695]

# %% [markdown]
# **You can add your answers here itself. (20 points)**
#
# **Dataset 1:
# 1.1) What is the range of the data values, and how are they distributed across the range? Are there any notable peaks (modes) in the histogram?**
#
# The range is from under 30 to just above 70. The data is right-skewed and there is a mode in the 40-50 range.
#
# **1.2) Is the distribution of data in Dataset 1 symmetrical, or does it exhibit skewness? If skewness is present, is it positive or negative?**
#
# It is not perfectly symmetrical, showing a slight right-skewed distribution. Since it is right-skewed, it is a positive skew.
#
# **1.3) What is the frequency of data points falling within specific intervals (e.g., 40-50, 50-60)? Are there intervals with significantly higher or lower frequencies?**
#
# The 30-40 interval doesn't go past a frequency of 3.
#
# The 40-50 interval has the the mode and the highest frequncies, the mode having a frequency of 9, and other peaks being high in this frequency. There is one bar with a low frequency of 2.
#
# The 50-60 has the second highest peak at 7, and other bars here are also high.
#
# Finally, the 60-70 interval is low, looking similar to 30-40 but perhaps with a bit more frequency.
#
# **Dataset 2:
# 2.1)Are there any outliers or extreme values in Dataset 2 that stand out when plotted in a histogram? How do these outliers affect the overall distribution?**
#
# Yes, with bins=30, we can see a few bars in the 40-50 interval that may be considered outliers. These outliers affect the overall distribution by contributing to the right-skewed distribution, and they certainly would affect the mean of this histogram.
#
# **2.2) Does the histogram for Dataset 2 suggest a normal (bell-shaped) distribution, or does it show a different pattern (e.g., bimodal, uniform)?**
#
# Dataset 2 shows a right-skewed (positive) unimodal distribution. It does not show a normal (bell-shaped) distribution.
#
# **2.3)What is the most common range (mode) for data points in Dataset 2? How does the frequency of this range compare to other ranges?**
#
# The 0-10 interval has by far the highest frequency and has the mode. It has significantly more frequency than any other range.
#
# **Dataset 3:
# 3.1) Does Dataset 3 have any clusters or groupings of data points that can be identified through the histogram? How many clusters are there, and where are they located?**
#
# Yes, Dataset 3 is bimodal. One mode is at the positive end of the 20-30 interval, and the second mode is on the positive end of the 60-70 interval.
#
# **3.2) What proportion of data points in Dataset 3 fall within one standard deviation of the mean, assuming the data is normally distributed? How does this compare with actual observations?**
#
#
#
# **Dataset 4:
# 4.1) Are there any significant gaps or empty bins in the histogram of Dataset 4? What might these gaps indicate about the distribution?**
#
# There is a large gap between the mid-frequencies of the 60-80 interval and the later end and parts of the 100-120 and 120-140 intervals.
#
# The two intervals ranging from 100-140 represent an outlier in the histogram.
#
# **4.2) Considering Dataset 4’s histogram, how does the spread of data compare to the mean? Is the data tightly clustered around the mean, or is there a wide spread?**
#
# The mean will be heavily influenced by the outliers in the 100-140 interval ranges. There's a wide spread because of these.

# %%
#Copy and paste your code in this cell (10 points)


import matplotlib.pyplot as plt
import numpy as np

dataset_1=[58.723206367206785, 51.83342005738352, 71.89802933217672, 41.91701714644849, 41.602781578192236, 44.00607354555978, 28.76104275690193, 44.74244978319239, 42.40867338446302, 51.50393786476208, 53.41755975777159, 68.76170839215887, 59.5042383818605, 44.23096344337597, 41.01585328651642, 54.919191715065054, 36.797667929793576, 68.31458765854353, 61.79440120721287, 45.30824347895295, 32.868654709091224, 63.538723741654124, 48.85460154747382, 62.378163119734616, 34.05572341205633, 44.00624977046227, 50.05243699718183, 50.46980593764742, 45.49934528520756, 56.228499323474985, 39.32379570617405, 48.576205149787064, 51.20295631711899, 55.14438834058749, 57.1161487808889, 38.75357908162131, 34.65885829264378, 62.77676821898509, 53.323140119795916, 42.51513463443446, 65.51151975522524, 51.156746342928585, 61.792971840638266, 50.67518481410109, 70.60747924881987, 67.55340842443204, 47.51035851520926, 59.71570950954356, 56.45375949585147, 63.68631557532349, 40.35076539419896, 56.86051459998439, 60.58424486849588, 32.41260513576886, 38.16741487334225, 29.607678222398995, 47.305931655554424, 57.17542255795962, 65.02357052096028, 50.74094780419775, 66.28615545571292, 36.198985417851084, 32.96617560644845, 49.44452301103381, 53.840654489393074, 49.67305251905907, 29.325578999601234, 49.10879960487212, 36.95530499495147, 56.69672548830039, 53.66598246096848, 40.60120213672645, 44.861330826633065, 39.40786478111048, 49.37320902726828, 59.551423205012384, 40.14273953664456, 55.040465155178445, 44.69742381627559, 42.07127167737656, 48.929696400454425, 39.64757677580626, 44.46350694652818, 38.021221074111516, 69.6472513291639, 50.35263551971729, 43.00274492007414, 52.13979910734222, 48.8767195030917, 47.79030400466777, 56.14166700043425, 57.57507710047305, 44.69498852389472, 44.2418175935532, 47.24948302848356, 26.98078835264415, 34.84808937801448, 63.66874267444525, 66.44967713501283, 47.50963960443622]
dataset_2=[0.37372952321478464, 2.909366218823972, 12.494918749560258, 22.557667543306135, 7.167791122084008, 7.5952950235306895, 1.1336133854066337, 5.9314324608355085, 7.6060679905529, 2.7769280326065333, 3.1367461187854384, 4.73664984802472, 0.20275360750314514, 3.8872476125613575, 2.3755693562362987, 3.9674923023198265, 1.2756310328478127, 22.120798999430246, 9.003988138795599, 11.366329578930316, 15.567090323777911, 6.900364218488852, 0.9093209451745585, 7.702583632948226, 8.839230578713735, 13.682166488084093, 5.6503464938298205, 1.3648466672931223, 3.337621802617039, 4.511148254746234, 10.382246116218617, 8.457817212014195, 4.402067596518061, 43.06195772169812, 9.308330084672093, 2.7079452875679992, 1.0734300462488686, 1.6588829258982587, 2.8230684939514097, 1.7516487495429403, 2.064917454545804, 3.3560584821544652, 1.90402433662887, 22.707514493559152, 0.8363571259200016, 7.434123501127027, 5.283055564893023, 40.3864216601592, 1.188273456974049, 5.072579937424305, 34.89059664126715, 20.062440619681546, 16.986630340361796, 2.9827508353350463, 1.873995327864875, 11.045595986817835, 26.503850949599553, 8.136504219047422, 8.477275614585865, 3.284750308106508, 14.674737584120885, 2.0707798214607083, 3.910878131192326, 5.541445500698305, 7.084849626446985, 2.7761258356960585, 1.2198327214413545, 9.431996574293565, 3.4056336843654176, 8.704530682924435, 1.676647527706798, 6.561213780285275, 7.605472481290779, 0.5321465145712133, 4.103836013804233, 1.443493268319316, 0.6547225877252488, 46.012013113953245, 3.8913002251942026, 16.600706137698985, 2.938888342934014, 11.441413510203516, 14.280662228282086, 9.054465941691397, 6.378566440452717, 5.307578135053777, 4.290433017039748, 26.52556048220781, 17.75607071141798, 33.53176389415692, 1.3272854183610554, 13.125513634605074, 27.861272652612406, 1.9995580970079767, 0.6881031747249687, 13.513931531886222, 8.544271441986698, 18.44077141321478, 1.505582464141926, 15.860501110318681]
dataset_3=[27.561968879637533, 27.837209060901895, 31.972260711891483, 27.895077595898684, 31.448874284482066, 40.37700399322719, 34.35562351715846, 28.369882339160796, 36.00606961081972, 27.959623134892244, 19.80937732411073, 24.95956844541298, 20.646040394870724, 28.24243257979346, 30.092091895947757, 38.382186561376415, 31.634636868820813, 28.90449735595568, 34.14702790591745, 18.944323454960575, 31.178072790542828, 33.85432596943483, 22.607068771100792, 35.71877021603464, 31.69248203747207, 27.923560430495993, 33.163909330531425, 41.35346428902198, 30.909331275292477, 31.24110293150168, 27.70319550229878, 25.75077815267604, 34.15167908272123, 25.719580870455665, 30.357831186096963, 27.611712766174417, 32.39489912873196, 31.66831052643474, 35.1876997212895, 27.449918005726264, 28.650625323533145, 25.106181421088465, 27.77853369961944, 31.88650246522426, 33.78494308322676, 25.389173379111874, 34.3480296005283, 36.778189294024756, 32.067174516118506, 39.38397906279033, 66.13105400448214, 63.776726483442914, 61.10639875547861, 77.48022155744592, 73.27182828177028, 69.72207664544773, 71.3998431315991, 64.37255476350812, 82.22875989808414, 70.64610590987614, 70.54697397302446, 73.62883311949346, 72.40504615868356, 71.11942012139566, 66.04762772277344, 72.35734178567998, 79.41012248237517, 76.7271002307749, 77.96593313319698, 67.44392161784407, 65.0519758987071, 69.37106539950176, 70.27862456144348, 75.47095759235474, 61.5376768514259, 77.64775159730307, 69.20996050710505, 67.8655946502629, 64.93947812369916, 61.72571664067115, 74.11585291980957, 70.36658983594202, 63.55019550129473, 63.52460613968192, 68.32107650354936, 78.34510762644696, 68.70204324318198, 62.48428523440947, 68.77128467957027, 68.63638215126164, 56.515566785292144, 69.72852566741093, 68.84532734895662, 73.48103182406709, 79.24478047472672, 75.63282514773879, 68.65555654722584, 64.46737045629165, 82.8667990162493, 70.29609217007244]
dataset_4=[50.13929291912946, 49.758749128899964, 51.98084760767855, 48.556395880760576, 44.26337993119763, 44.53141058759608, 49.672467297840015, 44.56575228866235, 42.871542173228356, 51.064302276918966, 47.450227825791444, 65.0399298858269, 23.490301916069882, 60.91506851922462, 62.46085192497629, 29.266097675918505, 46.573124059196516, 46.28559134004209, 35.924883052821784, 42.22183312409125, 38.894241545341714, 67.52270443423623, 59.35678393147461, 62.71555094994159, 57.21672064043235, 38.70948228782771, 44.75479733720226, 54.89374561227918, 37.778721911080545, 57.12998430172388, 47.59674601841865, 46.251791924504026, 57.10959968203491, 54.4426331148604, 46.3903383418092, 61.59329803364248, 39.189366724001026, 56.15935606944264, 55.93101257968384, 46.904535606860094, 53.26133022242118, 37.488864236146966, 59.24027019206901, 48.15097863557011, 44.772769794809605, 60.49009225836889, 42.95656309457241, 35.91538703636441, 34.433708264760966, 56.06009951345639, 37.19570647503717, 67.54794181984364, 29.18070592116278, 66.96456368290038, 52.11017467202618, 49.032868881296075, 44.550809131910505, 53.991361143520706, 49.62365297575152, 61.03301882016521, 51.142276486620396, 51.50301761461878, 46.36387787786144, 49.43054376278933, 53.07801768892059, 32.89831607343375, 36.518145778942866, 57.43264094022715, 51.708654381279416, 48.16016663647321, 50.184339330653934, 53.47581705361671, 44.60240319690639, 42.216952745976876, 51.958452550976816, 40.21627222384968, 54.082527557144715, 32.9741639576216, 60.29155637325644, 54.72597482413043, 52.56029734313876, 59.82690983945514, 66.65474444462576, 60.1437006501813, 31.591257686683548, 37.204230332642986, 43.75181422304321, 50.26091050210834, 55.17659020469123, 42.742561868465344, 51.86766764477078, 42.44617067646678, 43.884821970080516, 35.93338903151778, 40.76766753889096, 113.24157697191833, 115.12063373511333, 125.2682089830392, 115.25300555584029, 133.16191032418695]

# Creates a figure of 2x2s
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

bins = 30

# Histogram 1
axs[0, 0].hist(dataset_1, bins, color='blue', edgecolor='black')
axs[0, 0].set_title('Histogram of Dataset 1')
axs[0, 0].set_xlabel('Value')
axs[0, 0].set_ylabel('Frequency')

# Histogram 2
axs[0, 1].hist(dataset_2, bins, color='orange', edgecolor='black')
axs[0, 1].set_title('Histogram of Dataset 2')
axs[0, 1].set_xlabel('Value')
axs[0, 1].set_ylabel('Frequency')

# Histogram 3
axs[1, 0].hist(dataset_3, bins, color='green', edgecolor='black')
axs[1, 0].set_title('Histogram of Dataset 3')
axs[1, 0].set_xlabel('Value')
axs[1, 0].set_ylabel('Frequency')

# Histogram 4
axs[1, 1].hist(dataset_4, bins, color='purple', edgecolor='black')
axs[1, 1].set_title('Histogram of Dataset 4')
axs[1, 1].set_xlabel('Value')
axs[1, 1].set_ylabel('Frequency')

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show()

# %% [markdown]
# **PART B
# Use the above dataset and plot four boxplot in a sngle chart (NOT subplots) and compare the dataset.**

# %%
# Give your code for Boxplot chart in this cell (10 points)
import matplotlib.pyplot as plt
import numpy as np

dataset_1=[58.723206367206785, 51.83342005738352, 71.89802933217672, 41.91701714644849, 41.602781578192236, 44.00607354555978, 28.76104275690193, 44.74244978319239, 42.40867338446302, 51.50393786476208, 53.41755975777159, 68.76170839215887, 59.5042383818605, 44.23096344337597, 41.01585328651642, 54.919191715065054, 36.797667929793576, 68.31458765854353, 61.79440120721287, 45.30824347895295, 32.868654709091224, 63.538723741654124, 48.85460154747382, 62.378163119734616, 34.05572341205633, 44.00624977046227, 50.05243699718183, 50.46980593764742, 45.49934528520756, 56.228499323474985, 39.32379570617405, 48.576205149787064, 51.20295631711899, 55.14438834058749, 57.1161487808889, 38.75357908162131, 34.65885829264378, 62.77676821898509, 53.323140119795916, 42.51513463443446, 65.51151975522524, 51.156746342928585, 61.792971840638266, 50.67518481410109, 70.60747924881987, 67.55340842443204, 47.51035851520926, 59.71570950954356, 56.45375949585147, 63.68631557532349, 40.35076539419896, 56.86051459998439, 60.58424486849588, 32.41260513576886, 38.16741487334225, 29.607678222398995, 47.305931655554424, 57.17542255795962, 65.02357052096028, 50.74094780419775, 66.28615545571292, 36.198985417851084, 32.96617560644845, 49.44452301103381, 53.840654489393074, 49.67305251905907, 29.325578999601234, 49.10879960487212, 36.95530499495147, 56.69672548830039, 53.66598246096848, 40.60120213672645, 44.861330826633065, 39.40786478111048, 49.37320902726828, 59.551423205012384, 40.14273953664456, 55.040465155178445, 44.69742381627559, 42.07127167737656, 48.929696400454425, 39.64757677580626, 44.46350694652818, 38.021221074111516, 69.6472513291639, 50.35263551971729, 43.00274492007414, 52.13979910734222, 48.8767195030917, 47.79030400466777, 56.14166700043425, 57.57507710047305, 44.69498852389472, 44.2418175935532, 47.24948302848356, 26.98078835264415, 34.84808937801448, 63.66874267444525, 66.44967713501283, 47.50963960443622]
dataset_2=[0.37372952321478464, 2.909366218823972, 12.494918749560258, 22.557667543306135, 7.167791122084008, 7.5952950235306895, 1.1336133854066337, 5.9314324608355085, 7.6060679905529, 2.7769280326065333, 3.1367461187854384, 4.73664984802472, 0.20275360750314514, 3.8872476125613575, 2.3755693562362987, 3.9674923023198265, 1.2756310328478127, 22.120798999430246, 9.003988138795599, 11.366329578930316, 15.567090323777911, 6.900364218488852, 0.9093209451745585, 7.702583632948226, 8.839230578713735, 13.682166488084093, 5.6503464938298205, 1.3648466672931223, 3.337621802617039, 4.511148254746234, 10.382246116218617, 8.457817212014195, 4.402067596518061, 43.06195772169812, 9.308330084672093, 2.7079452875679992, 1.0734300462488686, 1.6588829258982587, 2.8230684939514097, 1.7516487495429403, 2.064917454545804, 3.3560584821544652, 1.90402433662887, 22.707514493559152, 0.8363571259200016, 7.434123501127027, 5.283055564893023, 40.3864216601592, 1.188273456974049, 5.072579937424305, 34.89059664126715, 20.062440619681546, 16.986630340361796, 2.9827508353350463, 1.873995327864875, 11.045595986817835, 26.503850949599553, 8.136504219047422, 8.477275614585865, 3.284750308106508, 14.674737584120885, 2.0707798214607083, 3.910878131192326, 5.541445500698305, 7.084849626446985, 2.7761258356960585, 1.2198327214413545, 9.431996574293565, 3.4056336843654176, 8.704530682924435, 1.676647527706798, 6.561213780285275, 7.605472481290779, 0.5321465145712133, 4.103836013804233, 1.443493268319316, 0.6547225877252488, 46.012013113953245, 3.8913002251942026, 16.600706137698985, 2.938888342934014, 11.441413510203516, 14.280662228282086, 9.054465941691397, 6.378566440452717, 5.307578135053777, 4.290433017039748, 26.52556048220781, 17.75607071141798, 33.53176389415692, 1.3272854183610554, 13.125513634605074, 27.861272652612406, 1.9995580970079767, 0.6881031747249687, 13.513931531886222, 8.544271441986698, 18.44077141321478, 1.505582464141926, 15.860501110318681]
dataset_3=[27.561968879637533, 27.837209060901895, 31.972260711891483, 27.895077595898684, 31.448874284482066, 40.37700399322719, 34.35562351715846, 28.369882339160796, 36.00606961081972, 27.959623134892244, 19.80937732411073, 24.95956844541298, 20.646040394870724, 28.24243257979346, 30.092091895947757, 38.382186561376415, 31.634636868820813, 28.90449735595568, 34.14702790591745, 18.944323454960575, 31.178072790542828, 33.85432596943483, 22.607068771100792, 35.71877021603464, 31.69248203747207, 27.923560430495993, 33.163909330531425, 41.35346428902198, 30.909331275292477, 31.24110293150168, 27.70319550229878, 25.75077815267604, 34.15167908272123, 25.719580870455665, 30.357831186096963, 27.611712766174417, 32.39489912873196, 31.66831052643474, 35.1876997212895, 27.449918005726264, 28.650625323533145, 25.106181421088465, 27.77853369961944, 31.88650246522426, 33.78494308322676, 25.389173379111874, 34.3480296005283, 36.778189294024756, 32.067174516118506, 39.38397906279033, 66.13105400448214, 63.776726483442914, 61.10639875547861, 77.48022155744592, 73.27182828177028, 69.72207664544773, 71.3998431315991, 64.37255476350812, 82.22875989808414, 70.64610590987614, 70.54697397302446, 73.62883311949346, 72.40504615868356, 71.11942012139566, 66.04762772277344, 72.35734178567998, 79.41012248237517, 76.7271002307749, 77.96593313319698, 67.44392161784407, 65.0519758987071, 69.37106539950176, 70.27862456144348, 75.47095759235474, 61.5376768514259, 77.64775159730307, 69.20996050710505, 67.8655946502629, 64.93947812369916, 61.72571664067115, 74.11585291980957, 70.36658983594202, 63.55019550129473, 63.52460613968192, 68.32107650354936, 78.34510762644696, 68.70204324318198, 62.48428523440947, 68.77128467957027, 68.63638215126164, 56.515566785292144, 69.72852566741093, 68.84532734895662, 73.48103182406709, 79.24478047472672, 75.63282514773879, 68.65555654722584, 64.46737045629165, 82.8667990162493, 70.29609217007244]
dataset_4=[50.13929291912946, 49.758749128899964, 51.98084760767855, 48.556395880760576, 44.26337993119763, 44.53141058759608, 49.672467297840015, 44.56575228866235, 42.871542173228356, 51.064302276918966, 47.450227825791444, 65.0399298858269, 23.490301916069882, 60.91506851922462, 62.46085192497629, 29.266097675918505, 46.573124059196516, 46.28559134004209, 35.924883052821784, 42.22183312409125, 38.894241545341714, 67.52270443423623, 59.35678393147461, 62.71555094994159, 57.21672064043235, 38.70948228782771, 44.75479733720226, 54.89374561227918, 37.778721911080545, 57.12998430172388, 47.59674601841865, 46.251791924504026, 57.10959968203491, 54.4426331148604, 46.3903383418092, 61.59329803364248, 39.189366724001026, 56.15935606944264, 55.93101257968384, 46.904535606860094, 53.26133022242118, 37.488864236146966, 59.24027019206901, 48.15097863557011, 44.772769794809605, 60.49009225836889, 42.95656309457241, 35.91538703636441, 34.433708264760966, 56.06009951345639, 37.19570647503717, 67.54794181984364, 29.18070592116278, 66.96456368290038, 52.11017467202618, 49.032868881296075, 44.550809131910505, 53.991361143520706, 49.62365297575152, 61.03301882016521, 51.142276486620396, 51.50301761461878, 46.36387787786144, 49.43054376278933, 53.07801768892059, 32.89831607343375, 36.518145778942866, 57.43264094022715, 51.708654381279416, 48.16016663647321, 50.184339330653934, 53.47581705361671, 44.60240319690639, 42.216952745976876, 51.958452550976816, 40.21627222384968, 54.082527557144715, 32.9741639576216, 60.29155637325644, 54.72597482413043, 52.56029734313876, 59.82690983945514, 66.65474444462576, 60.1437006501813, 31.591257686683548, 37.204230332642986, 43.75181422304321, 50.26091050210834, 55.17659020469123, 42.742561868465344, 51.86766764477078, 42.44617067646678, 43.884821970080516, 35.93338903151778, 40.76766753889096, 113.24157697191833, 115.12063373511333, 125.2682089830392, 115.25300555584029, 133.16191032418695]

# Creates box plot by passing datasets as an array
plt.boxplot([dataset_1,dataset_2,dataset_3,dataset_4], patch_artist=True, vert=False)
plt.title('Box Plot')
plt.ylabel('Dataset')
plt.xlabel('Values')

# Display the plot
plt.show()

# %% [markdown]
# **Write your comparison report of boxplot chart here. (10 points)**
#
# In the above box plot, we can see all four datasets compared to each other. Notice dataset 2 and 4's prominent outliers, while dataset 1 and 3 lack any.
# It's easy to see dataset 1's mostly symmetrical distribution, the heavy right-skewed distribution of dataset 2, mostly symmetrical distribution of dataset 3, and the right-skewed distribution of dataset 4.

# %% [markdown]
# **PART C**
#
# **Go to the below link, observe the visualization and answer all the questions below (10 points)**
# https://public.tableau.com/app/profile/wjsutton/viz/olympic_ages/TheAgeofOlympians?utm_campaign=2018128_TPublic_APROM_USCA_en-US_2019-09-20_T1-VOTD-Ongoing&utm_medium=Email&utm_source=Eloqua&domain=msudenver.edu&eid=CTBLS000052560594&d=7013y000000vYh9

# %% [markdown]
# **1) What is the most common age group for Olympic athletes in the "All discipline" histogram??**
#
# ***A) 15-19
# B) 20-24
# C) 25-29
# D) 30-34***
#
# C) 25-29.
# 20-24 and 25-29 visually have the most athletes, but there are 4,993 total atheletes in the 20-24 age group, and 5,339 in the 25-29 age group.

# %% [markdown]
# **2) Which age group has the least number of athletes in the "All discipline" histogram??**
#
# ***A) 10-14
# B) 35-39
# C) 40-44
# D) 45-49***
#
# A) 10-14.

# %% [markdown]
# **3) How many athletes are in the 25-29 age group in the "All discipline" histogram??**
#
# ***A) Around 1,500
# B) Around 2,500
# C) Around 3,500
# D) Around 4,500***
#
# D) Around 4,500. More specifically, 4,993.

# %% [markdown]
# **4) Which gender has more athletes in the 20-24 age group in the "All discipline" histogram?**
#
# ***A) Male
# B) Female
# C) Equal
# D) Not shown***
#
# A) Male. There are 2,556 male athletes in the 20-24 age group, and 2,437 female atheletes in the 20-24 age group.

# %% [markdown]
# **5) Is there a noticeable difference in the distribution of ages between male and female athletes? Explain**
#
# No, I don't see a significant difference in the distribution of ages between male and female athletes. Both have modes at 24 and 25 (female and male, respectively), and then slowly taper off as athletes get older.

# %% [markdown]
# **6) What is the age of the youngest Olympian shown in the 'All discipline" histogram?**
#
# ***A) 10
# B) 12
# C) 14
# D) 16***
#
# C) 14. There were 13 female athletes that were 14 years old.

# %% [markdown]
# **7) What trend is observed in the histogram regarding age and number of athletes in Skateboarding?**
#
# The median for female athlete ages and male athlete ages is quite different - most female athletes are younger, while male athletes tend to be older, even when accounting for the outliers.
# There also seems to be a higher frequency of female athletes close in age, while the male athletes are spread out.

# %% [markdown]
# **8) What qualifies as an outlier in the context of the histogram?**
#
# Technically, if a datapoint can be found outside the ranges of ((1.5 * IQR) - Q1) -> ((1.5 * IQR) + Q3), then it can be considered an outlier.
#
# More pragmactically, it's a datapoint that falls outside the average datapoints of a dataset.

# %% [markdown]
# **9) Which histograms shows highest outliers? Do you see any reasons for that (second answer is your own insights from the chart).**
#
# The histograms outliers are:
# - Diving
# - Equestrian
# - Golf
# - Modern Pentathlon
# - Rhythmic Gymnastics
# - Rowing
# - Shooting
# - Skateboarding
# - Sport Climbing
# - Surfing
# - Table Tennis
# - Taekwondo
# - Weightlifting
# - Wrestling
#
# Of those, Table Tennis and Skateboarding seem to have the most extreme outliers.
#
# It's difficult to pinpoint why, but for table tennis, it may be because the sport is popular with older generations and doesn't require as much physical effort as other sports (swimming, running, etc) (as a personal note, my nearly 70-year old grandfather still plays table tennis competitively in his town in France).
#
# Skateboarding is more perplexing, as it's a sport that requires physical effort, but icons like Tony Hawk may influence an older generation to continue skating in old age.

# %% [markdown]
# **10) Can you bring any five interesting insights from the visualization.**
#
# 1. There are two (Artistic Swimming and Rhythmic Gymnastics) sports with only female athletes.
# 2. Football has a severe drop-off in male athletes past age 23, going from 68 at 23 years old to 8 at 24 years old.
# 3. Equestrian and Shooting seem to be the sports with the shallowest frequency of age groups. These two sports' athletes are very spread out in age.
# 4. In Cycling Road, the mode for male athletes is age 24, but looks like an exact opposite of the 24 year old female athletes in this sport. There's a direct flip of high frequency of males and low frequency of females.
# 5. In trampoline gymnastics, female athletes has a mode at age 25, and male athletes are bimodal at ages 25 and 29, but modes for both female and male athletes are significantly larger than the rest of the bars in the histogram.
